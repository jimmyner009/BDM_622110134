# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-approval-prediction/credit_record.csv
# /kaggle/input/credit-card-approval-prediction/application_record.csv

# %%
df = pd.read_csv('../input/credit-card-approval-prediction/application_record.csv',header=0)

# %%
df_label = pd.read_csv('../input/credit-card-approval-prediction/credit_record.csv',header=0)

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0               Working               Higher education
# 1               427500.0               Working               Higher education
# 2               112500.0               Working  Secondary / secondary special
# 3               270000.0  Commercial associate  Secondary / secondary special
# 4               270000.0  Commercial associate  Secondary / secondary special
# ...                  ...                   ...                            ...
# 438552          135000.0             Pensioner  Secondary / secondary special
# 438553          103500.0               Working  Secondary / secondary special
# 438554           54000.0  Commercial associate               Higher education
# 438555           72000.0             Pensioner  Secondary / secondary special
# 438556          121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage   Rented apartment      -12005          -4542
# 1             Civil marriage   Rented apartment      -12005          -4542
# 2                    Married  House / apartment      -21474          -1134
# 3       Single / not married  House / apartment      -19110          -3051
# 4       Single / not married  House / apartment      -19110          -3051
# ...                      ...                ...         ...            ...
# 438552             Separated  House / apartment      -22717         365243
# 438553  Single / not married  House / apartment      -15939          -3007
# 438554  Single / not married       With parents       -8169           -372
# 438555               Married  House / apartment      -21673         365243
# 438556               Married  House / apartment      -18858          -1201
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0             NaN
# 1                1                1           0           0             NaN
# 2                1                0           0           0  Security staff
# 3                1                0           1           1     Sales staff
# 4                1                0           1           1     Sales staff
# ...            ...              ...         ...         ...             ...
# 438552           1                0           0           0             NaN
# 438553           1                0           0           0        Laborers
# 438554           1                1           0           0     Sales staff
# 438555           1                0           0           0             NaN
# 438556           1                0           1           0     Sales staff
#
#         CNT_FAM_MEMBERS
# 0                   2.0
# 1                   2.0
# 2                   2.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 438552              1.0
# 438553              1.0
# 438554              1.0
# 438555              2.0
# 438556              2.0
#
# [438557 rows x 18 columns]

# %%
df_label
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
df_label.groupby('ID')['STATUS'].count()
# Out:
# ID
# 5001711     4
# 5001712    19
# 5001713    22
# 5001714    15
# 5001715    60
#            ..
# 5150482    18
# 5150483    18
# 5150484    13
# 5150485     2
# 5150487    30
# Name: STATUS, Length: 45985, dtype: int64

# %%
df_label['STATUS'], labels = pd.factorize(df_label['STATUS'])

# %%
labels
# Out:
# Index(['X', '0', 'C', '1', '2', '3', '4', '5'], dtype='object')

# %%
df_label_clean = df_label[df_label['STATUS'] != 0]

# %%
df_label_clean['STATUS'][df_label['STATUS'] > 2] = 10
df_label_clean['STATUS'][df_label['STATUS'] <= 2] = 0
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
df_label_clean.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0     825151
# 10     14194
# Name: STATUS, dtype: int64

# %%
df_label_group = df_label_clean.groupby('ID').mean()

# %%
df_label_group['STATUS'][df_label_group['STATUS'] > 0] = 1
df_label_group['STATUS'][df_label_group['STATUS'] <= 0] = 0

# %%
df_label_group.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0.0    36099
# 1.0     5350
# Name: STATUS, dtype: int64

# %%
client_id = df_label_group.index.values
client_label = df_label_group['STATUS'].values

# %%
client_id
# Out:
# array([5001711, 5001712, 5001717, ..., 5150484, 5150485, 5150487])

# %%
df.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05  -15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609375e+06       0.000000      1.215000e+05  -19483.000000
# 50%    6.047745e+06       0.000000      1.607805e+05  -15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05  -12514.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE     FLAG_PHONE  \
# count  438557.000000    438557.0    438557.000000  438557.000000
# mean    60563.675328         1.0         0.206133       0.287771
# std    138767.799647         0.0         0.404527       0.452724
# min    -17531.000000         1.0         0.000000       0.000000
# 25%     -3103.000000         1.0         0.000000       0.000000
# 50%     -1467.000000         1.0         0.000000       0.000000
# 75%      -371.000000         1.0         0.000000       1.000000
# max    365243.000000         1.0         1.000000       1.000000
#
#           FLAG_EMAIL  CNT_FAM_MEMBERS
# count  438557.000000    438557.000000
# mean        0.108207         2.194465
# std         0.310642         0.897207
# min         0.000000         1.000000
# 25%         0.000000         2.000000
# 50%         0.000000         2.000000
# 75%         0.000000         3.000000
# max         1.000000        20.000000

# %%
df.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_BIRTH             False
# DAYS_EMPLOYED          False
# FLAG_MOBIL             False
# FLAG_WORK_PHONE        False
# FLAG_PHONE             False
# FLAG_EMAIL             False
# OCCUPATION_TYPE         True
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df.groupby('OCCUPATION_TYPE')['OCCUPATION_TYPE'].count()
# Out:
# OCCUPATION_TYPE
# Accountants              15985
# Cleaning staff            5845
# Cooking staff             8076
# Core staff               43007
# Drivers                  26090
# HR staff                   774
# High skill tech staff    17289
# IT staff                   604
# Laborers                 78240
# Low-skill Laborers        2140
# Managers                 35487
# Medicine staff           13520
# Private service staff     3456
# Realty agents             1041
# Sales staff              41098
# Secretaries               2044
# Security staff            7993
# Waiters/barmen staff      1665
# Name: OCCUPATION_TYPE, dtype: int64

# %%
df_clean = df.dropna(axis = 0)

# %%
df_clean.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_BIRTH             False
# DAYS_EMPLOYED          False
# FLAG_MOBIL             False
# FLAG_WORK_PHONE        False
# FLAG_PHONE             False
# FLAG_EMAIL             False
# OCCUPATION_TYPE        False
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df_clean_drop = df_clean.drop(['DAYS_BIRTH', 'FLAG_EMAIL', 'FLAG_PHONE', 'FLAG_WORK_PHONE', 'FLAG_MOBIL', 'CODE_GENDER'], axis = 1)

# %%
df_clean_drop.isnull().any()
# Out:
# ID                     False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_EMPLOYED          False
# OCCUPATION_TYPE        False
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df_clean_drop
# Out:
#              ID FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 2       5008806            Y               Y             0          112500.0
# 3       5008808            N               Y             0          270000.0
# 4       5008809            N               Y             0          270000.0
# 5       5008810            N               Y             0          270000.0
# 6       5008811            N               Y             0          270000.0
# ...         ...          ...             ...           ...               ...
# 438541  6837707            N               Y             0          202500.0
# 438548  6839936            Y               Y             1          135000.0
# 438553  6840222            N               N             0          103500.0
# 438554  6841878            N               N             0           54000.0
# 438556  6842885            N               Y             0          121500.0
#
#             NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 2                    Working  Secondary / secondary special
# 3       Commercial associate  Secondary / secondary special
# 4       Commercial associate  Secondary / secondary special
# 5       Commercial associate  Secondary / secondary special
# 6       Commercial associate  Secondary / secondary special
# ...                      ...                            ...
# 438541               Working               Higher education
# 438548               Working  Secondary / secondary special
# 438553               Working  Secondary / secondary special
# 438554  Commercial associate               Higher education
# 438556               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_EMPLOYED  \
# 2                    Married  House / apartment          -1134
# 3       Single / not married  House / apartment          -3051
# 4       Single / not married  House / apartment          -3051
# 5       Single / not married  House / apartment          -3051
# 6       Single / not married  House / apartment          -3051
# ...                      ...                ...            ...
# 438541        Civil marriage  House / apartment          -2309
# 438548               Married  House / apartment          -2095
# 438553  Single / not married  House / apartment          -3007
# 438554  Single / not married       With parents           -372
# 438556               Married  House / apartment          -1201
#
#        OCCUPATION_TYPE  CNT_FAM_MEMBERS
# 2       Security staff              2.0
# 3          Sales staff              1.0
# 4          Sales staff              1.0
# 5          Sales staff              1.0
# 6          Sales staff              1.0
# ...                ...              ...
# 438541        Laborers              2.0
# 438548        Laborers              3.0
# 438553        Laborers              1.0
# 438554     Sales staff              1.0
# 438556     Sales staff              2.0
#
# [304354 rows x 12 columns]

# %%
df_clean_drop.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
df_clean_drop['FLAG_OWN_CAR'] = pd.factorize(df_clean_drop['FLAG_OWN_CAR'])[0]
df_clean_drop['FLAG_OWN_REALTY'] = pd.factorize(df_clean_drop['FLAG_OWN_REALTY'])[0]
df_clean_drop['NAME_INCOME_TYPE'] = pd.factorize(df_clean_drop['NAME_INCOME_TYPE'])[0]
df_clean_drop['NAME_EDUCATION_TYPE'] = pd.factorize(df_clean_drop['NAME_EDUCATION_TYPE'])[0]
df_clean_drop['NAME_FAMILY_STATUS'] = pd.factorize(df_clean_drop['NAME_FAMILY_STATUS'])[0]
df_clean_drop['NAME_HOUSING_TYPE'] = pd.factorize(df_clean_drop['NAME_HOUSING_TYPE'])[0]
df_clean_drop['OCCUPATION_TYPE'] = pd.factorize(df_clean_drop['OCCUPATION_TYPE'])[0]

# %%
df_clean_drop.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR             int64
# FLAG_OWN_REALTY          int64
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE         int64
# NAME_EDUCATION_TYPE      int64
# NAME_FAMILY_STATUS       int64
# NAME_HOUSING_TYPE        int64
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE          int64
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
X_clien_id = df_clean_drop['ID'].values
df_clean_drop = df_clean_drop.drop(['ID'], axis = 1)

# %%
X = df_clean_drop.values
X.shape
# Out:
# (304354, 11)

# %%
real_client_id = [item for item in X_client_id if item in client_id]

# %%
len(real_client_id)
# Out:
# 22737

# %%
y = np.array([client_label[np.where(client_id == item)][0] for item in real_client_id ])

# %%
X_final = [X[np.where(X_client_id == item), :][0] for item in real_client_id ]

# %%
X_real_final = np.vstack(X_final)

# %%
X_real_final.shape
# Out:
# (22737, 11)

# %%
len(y)
# Out:
# 22737

# %%
sum(y==1)
# Out:
# 3089

# %%
from imblearn.under_sampling import RandomUnderSampler
sm = RandomUnderSampler(random_state=1)
X_res, y_res = sm.fit_resample(X_real_final, y)

# %%
X_res.shape
# Out:
# (6178, 11)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=1)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(X_train)
X_train_norm =  scaler.transform(X_train)
X_val_norm = scaler.transform(X_val)
X_test_norm = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

params = {'C': [1, 2, 4, 8, 16]}
clf = GridSearchCV(LogisticRegression(random_state=0, solver='liblinear'),params, cv=10)
clf.fit(X_train_norm, y_train)
print("Best params : " + str(clf.best_params_))
print("10CV accuracy : "+str(clf.best_score_*100))
# Out:
# Best params : {'C': 1}
# 10CV accuracy : 53.66749191390808

# %%
y_predict = clf.predict(X_test_norm)
print("Test accuracy : "+str(sum(y_test == y_predict)/len(y_test)*100))
# Out:
# Test accuracy : 51.94174757281553

# %%
import tensorflow as tf

# %%
tf.compat.v1.reset_default_graph() # Clear Model
np.random.seed(1) # Fix Randomness
tf.compat.v1.random.set_random_seed(1) # Fix Randomness

model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(300, activation='relu', input_shape=(11,)),
  tf.keras.layers.Dense(200, activation='relu'),
  tf.keras.layers.Dense(100, activation='relu'),
  tf.keras.layers.Dense(50, activation='relu'),
  tf.keras.layers.Dense(20, activation='relu'),
  tf.keras.layers.Dense(10, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')    
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 300)               3600
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               60200
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                1020
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                210
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 90,191
# Trainable params: 90,191
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
train_acc = list()
val_acc = list()
for i in range(0,100):
  history = model.fit(X_train_norm, y_train, epochs= 1, batch_size = 200, validation_data= (X_val_norm, y_val))
  tmp_avg = np.mean(history.history['accuracy'])
  tmp_avg_val = np.mean(history.history['val_accuracy'])
  train_acc.append(tmp_avg)
  val_acc.append(tmp_avg_val)
# Out:
# 16/16 [==============================] - 1s 25ms/step - loss: 0.6930 - accuracy: 0.5138 - val_loss: 0.6954 - val_accuracy: 0.5082
# 16/16 [==============================] - 1s 51ms/step - loss: 0.6881 - accuracy: 0.5440 - val_loss: 0.6961 - val_accuracy: 0.5095
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6867 - accuracy: 0.5481 - val_loss: 0.6965 - val_accuracy: 0.5158
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6858 - accuracy: 0.5538 - val_loss: 0.6968 - val_accuracy: 0.5171
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6848 - accuracy: 0.5579 - val_loss: 0.6975 - val_accuracy: 0.5133
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6830 - accuracy: 0.5598 - val_loss: 0.6972 - val_accuracy: 0.5107
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6811 - accuracy: 0.5591 - val_loss: 0.6960 - val_accuracy: 0.5183
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6786 - accuracy: 0.5658 - val_loss: 0.6945 - val_accuracy: 0.5272
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6763 - accuracy: 0.5708 - val_loss: 0.6941 - val_accuracy: 0.5322
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6728 - accuracy: 0.5765 - val_loss: 0.6931 - val_accuracy: 0.5297
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6695 - accuracy: 0.5825 - val_loss: 0.6923 - val_accuracy: 0.5461
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6668 - accuracy: 0.5908 - val_loss: 0.6932 - val_accuracy: 0.5310
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6626 - accuracy: 0.5904 - val_loss: 0.6925 - val_accuracy: 0.5436
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6587 - accuracy: 0.5879 - val_loss: 0.6919 - val_accuracy: 0.5398
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6550 - accuracy: 0.5920 - val_loss: 0.6962 - val_accuracy: 0.5436
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6500 - accuracy: 0.5980 - val_loss: 0.6942 - val_accuracy: 0.5525
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6458 - accuracy: 0.6022 - val_loss: 0.6950 - val_accuracy: 0.5310
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6403 - accuracy: 0.6145 - val_loss: 0.7011 - val_accuracy: 0.5525
# 16/16 [==============================] - 0s 16ms/step - loss: 0.6390 - accuracy: 0.6132 - val_loss: 0.7010 - val_accuracy: 0.5537
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6306 - accuracy: 0.6170 - val_loss: 0.7037 - val_accuracy: 0.5449
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6246 - accuracy: 0.6278 - val_loss: 0.7073 - val_accuracy: 0.5575
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6217 - accuracy: 0.6293 - val_loss: 0.7187 - val_accuracy: 0.5411
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6142 - accuracy: 0.6417 - val_loss: 0.7256 - val_accuracy: 0.5424
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6092 - accuracy: 0.6464 - val_loss: 0.7433 - val_accuracy: 0.5626
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6021 - accuracy: 0.6546 - val_loss: 0.7456 - val_accuracy: 0.5689
# 16/16 [==============================] - 0s 14ms/step - loss: 0.
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4762 - accuracy: 0.7410 - val_loss: 0.8905 - val_accuracy: 0.5702
# 16/16 [==============================] - 0s 13ms/step - loss: 0.4702 - accuracy: 0.7476 - val_loss: 0.9093 - val_accuracy: 0.5714
# 16/16 [==============================] - 0s 13ms/step - loss: 0.4636 - accuracy: 0.7565 - val_loss: 0.9316 - val_accuracy: 0.5740
# 16/16 [==============================] - 0s 13ms/step - loss: 0.4561 - accuracy: 0.7530 - val_loss: 0.9732 - val_accuracy: 0.5828
# 16/16 [==============================] - 0s 13ms/step - loss: 0.4606 - accuracy: 0.7479 - val_loss: 1.0155 - val_accuracy: 0.5702
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4684 - accuracy: 0.7413 - val_loss: 1.0209 - val_accuracy: 0.5613
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4752 - accuracy: 0.7483 - val_loss: 0.9460 - val_accuracy: 0.5727
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4683 - accuracy: 0.7454 - val_loss: 0.9436 - val_accuracy: 0.5689
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4568 - accuracy: 0.7549 - val_loss: 0.9661 - val_accuracy: 0.5752
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4401 - accuracy: 0.7694 - val_loss: 1.0517 - val_accuracy: 0.5702
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4403 - accuracy: 0.7726 - val_loss: 1.0457 - val_accuracy: 0.5714
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4450 - accuracy: 0.7634 - val_loss: 0.9808 - val_accuracy: 0.5727
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4402 - accuracy: 0.7647 - val_loss: 0.9659 - val_accuracy: 0.5702
# 16/16 [==============================] - 0s 13ms/step - loss: 0.4341 - accuracy: 0.7650 - val_loss: 0.9837 - val_accuracy: 0.5853
# 16/16 [==============================] - 0s 13ms/step - loss: 0.4279 - accuracy: 0.7761 - val_loss: 1.0144 - val_accuracy: 0.5740
# 16/16 [==============================] - 0s 13ms/step - loss: 0.4275 - accuracy: 0.7780 - val_loss: 1.0488 - val_accuracy: 0.5664
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4309 - accuracy: 0.7713 - val_loss: 1.0666 - val_accuracy: 0.5626
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4346 - accuracy: 0.7786 - val_loss: 1.0409 - val_accuracy: 0.5689
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4305 - accuracy: 0.7691 - val_loss: 1.0266 - val_accuracy: 0.5714
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4283 - accuracy: 0.7701 - val_loss: 1.0607 - val_accuracy: 0.5803
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4228 - accuracy: 0.7758 - val_loss: 1.0671 - val_accuracy: 0.5879
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4125 - accuracy: 0.7903 - val_loss: 1.0752 - val_accuracy: 0.5803
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4069 - accuracy: 0.7951 - val_loss: 1.1260 - val_accuracy: 0.5765
# 16/16 [==============================] - 0s 17ms/step - loss: 0.4115 - accuracy: 0.7881 - val_loss: 1.1286 - val_accuracy: 0.5740
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4212 - accuracy: 0.7802 - val_loss: 1.1024 - val_accuracy: 0.5575
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4215 - accuracy: 0.7802 - val_loss: 1.1138 - val_accuracy: 0.5727
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4127 - accuracy: 0.7856 - val_loss: 1.0693 - val_accuracy: 0.5752
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4066 - accuracy: 0.7891 - val_loss: 1.0675 - val_accuracy: 0.5841
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4022 - accuracy: 0.7887 - val_loss: 1.0550 - val_accuracy: 0.5664
# 16/16 [==============================] - 0s 16ms/step - loss: 0.3993 - accuracy: 0.7865 - val_loss: 1.1064 - val_accuracy: 0.5803
# 16/16 [==============================] - 0s 14ms/step - loss: 0.3965 - accuracy: 0.7910 - val_loss: 1.0979 - val_accuracy: 0.5613
# 16/16 [==============================] - 0s 14ms/step - loss: 0.3995 - accuracy: 0.7925 - val_loss: 1.1703 - val_accuracy: 0.5702
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4047 - accuracy: 0.7783 - val_loss: 1.1732 - val_accuracy: 0.5765
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4140 - accuracy: 0.7770 - val_loss: 1.1905 - val_accuracy: 0.5879
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4073 - accuracy: 0.7925 - val_loss: 1.1251 - val_accuracy: 0.5828

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.figure(num=None, figsize=(16, 8), dpi=90, facecolor='w', edgecolor='k')
plt.plot()
plt.plot(train_acc)
plt.plot(val_acc)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'val'], loc='upper left')
plt.show()

# %%
y_predict = np.round(model.predict(X_test_norm))
y_predict = [i[0] for i in y_predict.tolist()]
sum(y_predict == y_test)/len(y_test)
# Out:
# 0.6132686084142395

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
target_names = ['negative', 'positive']
C = confusion_matrix(y_test,y_predict) 
C = C / C.astype(np.float).sum(axis=1)*100
sns.heatmap(C, annot=True, fmt=".2f",cmap="GnBu",xticklabels=target_names, yticklabels=target_names)
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.show()
